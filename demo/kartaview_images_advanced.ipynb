# %%
import requests
import re
import json
import os
import pandas as pd
import sys
import numpy as np

# project lib
PROJECT_SRC_PATH = os.path.join( '/workspace/workspace/ufo-prediction', 'src-RCA-UFO')
sys.path.append(PROJECT_SRC_PATH)
import dataset

# %%
# Set a seed for reproducibility
np.random.seed(42)  # You can choose any number as your seed

# Define paths for data
path_data_NLD = os.path.join('/workspace/workspace/ufo-prediction', 'demo', 'df-NLD.pkl')
path_data_FRA = os.path.join('/workspace/workspace/ufo-prediction', 'demo', 'df-FRA.pkl')
path_data_ESP = os.path.join('/workspace/workspace/ufo-prediction', 'demo', 'df-ESP.pkl')
processed_df_NLD = "/workspace/workspace/ufo-prediction/demo/kartaview_key_NLD_adv.csv"
processed_df_ESP = "/workspace/workspace/ufo-prediction/demo/kartaview_key_ESP_adv.csv"
processed_df_FRA = "/workspace/workspace/ufo-prediction/demo/kartaview_key_FRA_adv.csv"
processed_df_ALL = "/workspace/workspace/ufo-prediction/demo/kartaview_key.csv"

# Image directory paths
image_dir_map = {
    'NLD': '/workspace/workspace/ufo-prediction/image_data_NLD_adv',
    'FRA': '/workspace/workspace/ufo-prediction/image_data_FRA_adv',
    'ESP': '/workspace/workspace/ufo-prediction/image_data_ESP_adv',
    'ALL': '/workspace/workspace/ufo-prediction/image_data'
}

# Ask for user input
country_code = input("Enter country code (FRA, NLD, ESP) or ALL: ").upper()

# Map user input to the correct path
path_data_map = {
    'NLD': processed_df_NLD,
    'FRA': processed_df_FRA,
    'ESP': processed_df_ESP,
    'ALL': processed_df_ALL
}

raw_data_path_map = {
'NLD': path_data_NLD,
'FRA': path_data_FRA,
'ESP': path_data_ESP
}
# Check if the input is valid
if country_code not in path_data_map:
    print("Invalid country code or specification. Please enter FRA, NLD, ESP, or ALL.")
else:
    processed_df_path = path_data_map[country_code]
    # Set directory based on country code
    current_directory = image_dir_map[country_code]

    # Check if the new directory exists, if not, create it
    if not os.path.exists(current_directory):
        os.makedirs(current_directory)
        print(f"Directory {current_directory} created.")
    else:
        print(f"Directory {current_directory} already exists.")

    # Process for ALL
    if country_code == 'ALL':
        if os.path.exists(processed_df_path):
            kartaview_keys = pd.read_csv(processed_df_path)
            print("Loaded processed DataFrame from", processed_df_path)
        else:
            print("Creating a new processed DataFrame for ALL")
            path_data_RCA = os.path.join(dataset.DATA_DIR, 'rca-ufo-merge_ALL.csv')
            df = pd.read_csv(path_data_RCA, encoding='latin1')
            kartaview_keys = df[['lon', 'lat','age_right', 'id', 'PropertyKey_ID']]
            kartaview_keys.to_csv(processed_df_path, index=False)
            

    # Process for FRA, NLD, ESP
    else:
        if os.path.exists(processed_df_path):
            kartaview_keys = pd.read_csv(processed_df_path)
            print("Loaded processed DataFrame from", processed_df_path)
        else:
            print(f"Creating a new processed DataFrame for {country_code}")
            df_path = raw_data_path_map[country_code]
            df = pd.read_pickle(df_path)
            print("Loaded DataFrame from", df_path)
            sampled_df = df.sample(n=1500000, random_state=42)
            kartaview_keys = sampled_df[['lon', 'lat', 'age', 'id']].rename(columns={'age': 'age_right'})
            kartaview_keys.to_csv(processed_df_path, index=False)

print(kartaview_keys)
# Out:
# Directory /workspace/workspace/ufo-prediction/image_data_NLD_adv already exists.
# Loaded processed DataFrame from /workspace/workspace/ufo-prediction/demo/kartaview_key_NLD_adv.csv
#               lon        lat  age_right                      id
# 0        6.540629  52.920211     2006.0    v0.1-NLD.1.9_1-12990
# 1        5.854499  51.956602     1976.0    v0.1-NLD.4.4_1-45356
# 2        3.484073  51.327285     1951.0     v0.1-NLD.12.9_1-110
# 3        6.308934  53.219335     1981.0     v0.1-NLD.5.8_1-1627
# 4        6.139037  51.365948     2013.0   v0.1-NLD.7.44_1-29441
# ...           ...        ...        ...                     ...
# 1342395  5.016727  51.584394     1982.0   v0.1-NLD.8.58_1-66422
# 1342396  5.964799  52.210063     1984.0    v0.1-NLD.4.3_1-86122
# 1342397  5.810202  51.975321     1917.0   v0.1-NLD.4.49_1-11930
# 1342398  4.996753  52.297225     1986.0   v0.1-NLD.9.4_1-156771
# 1342399  4.291625  52.068794     1991.0  v0.1-NLD.14.2_1-145141
#
# [1342400 rows x 4 columns]

# %%
print(current_directory)
print(kartaview_keys)
# Out:
# /workspace/workspace/ufo-prediction/image_data_NLD_adv
#               lon        lat  age_right                      id
# 0        4.500042  52.257291     1970.0   v0.1-NLD.14.55_1-2387
# 1        5.705976  51.242094     2014.0   v0.1-NLD.7.47_1-11753
# 2        6.237505  52.131841     1986.0    v0.1-NLD.4.61_1-2484
# 3        6.554392  53.002261     1963.0    v0.1-NLD.1.2_1-15263
# 4        5.184203  52.112901     1961.0   v0.1-NLD.11.8_1-11656
# ...           ...        ...        ...                     ...
# 1358995  5.016727  51.584394     1982.0   v0.1-NLD.8.58_1-66422
# 1358996  5.964799  52.210063     1984.0    v0.1-NLD.4.3_1-86122
# 1358997  5.810202  51.975321     1917.0   v0.1-NLD.4.49_1-11930
# 1358998  4.996753  52.297225     1986.0   v0.1-NLD.9.4_1-156771
# 1358999  4.291625  52.068794     1991.0  v0.1-NLD.14.2_1-145141
#
# [1359000 rows x 4 columns]

# %%
# Assuming current_directory and processed_df_path are set from the previous code chunk
print(f"Images will be saved in: {current_directory}")
print(f"Using kartaview_keys from: {processed_df_path}")

# Consistency check between image directory and kartaview_keys path
expected_csv_map = {
    '/workspace/workspace/ufo-prediction/image_data': '/workspace/workspace/ufo-prediction/demo/kartaview_key.csv',
    '/workspace/workspace/ufo-prediction/image_data_NLD': '/workspace/workspace/ufo-prediction/demo/kartaview_key_NLD.csv',
    '/workspace/workspace/ufo-prediction/image_data_FRA': '/workspace/workspace/ufo-prediction/demo/kartaview_key_FRA.csv',
    '/workspace/workspace/ufo-prediction/image_data_ESP': '/workspace/workspace/ufo-prediction/demo/kartaview_key_ESP.csv',
}

# Stop the code if using image_data directory
if current_directory == '/workspace/workspace/ufo-prediction/image_data':
    print("Download for the 'image_data' directory has already been completed. Stopping execution.")
    # Use `exit()` or `sys.exit()` depending on your environment
    exit()

if processed_df_path != expected_csv_map.get(current_directory):
    print("Inconsistency detected between the image directory and the kartaview_keys path. Please check.")
    exit()

image_count = {} 
print("Number of buildings remaining: ",len(kartaview_keys))

#Initialise a counter for the loop iterations
iteration_counter = 0

for index, row in kartaview_keys.iterrows():
    iteration_counter += 1 # Increment the counter with each iteration
    precision = 6  # Start with 6 decimal places
    success = False  # Flag to indicate if the request was successful

    while precision > 2 and not success:
        # Format lon and lat to the current precision
        lon = f"{row['lon']:.{precision}f}"
        lat = f"{row['lat']:.{precision}f}"

        # Construct the API URL
        url = "https://api.openstreetcam.org/2.0/photo/?lat={}&lng={}".format(lat, lon)

        # Send a GET request to the API
        response = requests.get(url)

        # Check if the request was successful
        if response.status_code == 200:
            data = response.json()
            url_pattern = r'https://storage\d+\.openstreetcam\.org/files/photo/\d+/\d+/\d+/[^"]+\.jpg'
            urls = re.findall(url_pattern, json.dumps(data))

            filtered_urls = [
                url for url in urls
                if not any(x in url.rsplit('/', 2)[-2] for x in ["{{sizeprefix}}", "proc"]) and
                ("th" in url.rsplit('/', 2)[-2] and not "lth" in url.rsplit('/', 2)[-2])
            ]

            if filtered_urls:
                # Initialize or update the image count for the current ID
                building_id = row['id']  # Assuming 'id' column exists in your DataFrame
                if building_id not in image_count:
                    image_count[building_id] = 0

                for image_url in filtered_urls:
                    image_count[building_id] += 1  # Increment the image count for the building
                    subscript = image_count[building_id]  # Subscript for the file name
                    file_name = f"{row['age_right']}_{building_id}_{subscript}.jpg"
                    file_path = os.path.join(current_directory, file_name)

                    # Check if the file already exists
                    if os.path.exists(file_path):
                        print(f"File already exists: {file_path}. Skipping download.")
                    else:
                        image_response = requests.get(image_url)

                        if image_response.status_code == 200:
                            with open(file_path, 'wb') as f:
                                f.write(image_response.content)
                            print("Image downloaded successfully: {}".format(file_path))
                        else:
                            print("Failed to download the image.")
                success = True  # Mark success as True to exit the while loop
            else:
                print("No suitable images found for location: lon={}, lat={}".format(lon, lat))
                precision -= 1  # Reduce precision by one decimal place
        else:
            print("Failed to retrieve data from the API for location: lon={}, lat={}. Trying with reduced precision.")
            

    # After processing, remove the row from df_subset
    kartaview_keys = kartaview_keys.drop(index)

    # Only save the updated DataFrame to a CSV file every 100th instance
    if iteration_counter % 100 == 0:
        print(f"Saving progress at iteration {iteration_counter} to {processed_df_path}. ")
        print("Number of buildings remaining: ",len(kartaview_keys))
        kartaview_keys.to_csv(processed_df_path, index=False)

    if not success:
        print("Unable to retrieve data from the API with sufficient precision for location: lon={}, lat={}".format(row['lon'], row['lat']))
        
if iteration_counter % 100 != 0:
    print(f"Saving final progress")
    print("Number of buildings remaining: ",len(kartaview_keys))
    kartaview_keys.to_csv(processed_df_path, index=False)
# Out:
# Images will be saved in: /workspace/workspace/ufo-prediction/image_data_NLD_adv
# Using kartaview_keys from: /workspace/workspace/ufo-prediction/demo/kartaview_key_NLD_adv.csv
# Inconsistency detected between the image directory and the kartaview_keys path. Please check.
# Number of buildings remaining:  1374300
# No suitable images found for location: lon=5.299930, lat=51.691141
# No suitable images found for location: lon=5.29993, lat=51.69114
# No suitable images found for location: lon=5.2999, lat=51.6911
# No suitable images found for location: lon=5.300, lat=51.691
# Unable to retrieve data from the API with sufficient precision for location: lon=5.299929642419115, lat=51.69114106978775
# No suitable images found for location: lon=4.597151, lat=52.453980
# No suitable images found for location: lon=4.59715, lat=52.45398
# No suitable images found for location: lon=4.5972, lat=52.4540
# No suitable images found for location: lon=4.597, lat=52.454
# Unable to retrieve data from the API with sufficient precision for location: lon=4.597150580921423, lat=52.453980461079375
# No suitable images found for location: lon=5.371916, lat=52.192266
# No suitable images found for location: lon=5.37192, lat=52.19227
# No suitable images found for location: lon=5.3719, lat=52.1923
# No suitable images found for location: lon=5.372, lat=52.192
# Unable to retrieve data from the API with sufficient precision for location: lon=5.37191610898059, lat=52.19226627444248
# No suitable images found for location: lon=5.375697, lat=52.182719
# No suitable images found for location: lon=5.37570, lat=52.18272
# No suitable images found for location: lon=5.3757, lat=52.1827
# No suitable images found for location: lon=5.376, lat=52.183
# Unable to retrieve data from the API with sufficient precision for location: lon=5.37569701238039, lat=52.18271929311192
# No suitable images found for location: lon=4.874479, lat=51.652676
# No suitable images found for location: lon=4.87448, lat=51.65268
# No suitable images found for location: lon=4.8745, lat=51.6527
# No suitable images found for location: lon=4.874, lat=51.653
# Unable to retrieve data from the API with sufficient precision for location: lon=4.874478984178321, lat=51.65267592762167
# No suitable images found for location: lon=4.507196, lat=51.929670
# No suitable images found for location: lon=4.50720, lat=51.92967
# No suitable images found for location: lon=4.5072, lat=51.9297
# No suitable images found for location: lon=4.507, lat=51.930
# Unable to retrieve data from the API with sufficient precision for location: lon=4.507196476880982, lat=51.92967015176259
# No suitable images found for location: lon=5.652657, lat=53.197977
# No suitable images found for location: lon=5.65266, lat=53.19798
# No suitable images found for location: lon=5.6527, lat=53.1980
# No suitable images found for location: lon=5.653, lat=53.198
# Unable to retrieve data from the API with sufficient precision for location: lon=5.652657251594685, lat=53.19797716553372
# No suitable images found for location: lon=4.903723, lat=51.806180
# No suitable images found for location: lon=4.90372, lat=51.80618
# No suitable images found for location: lon=4.9037, lat=51.8062
# No suitable images found for location: lon=4.904, lat=51.806
# Unable to retrieve data from the API with sufficient precision for location: lon=4.903722896454085, lat=51.80618032934469
# No suitable images found for location: lon=6.471679, lat=52.345269
# No suitable images found for location: lon=6.47168, lat=52.34527
# No suitable images found for location: lon=6.4717, lat=52.3453
# No suitable images found for location: lon=6.472, lat=52.345
# Unable to retrieve data from the API with sufficient precision for location: lon=6.471679192901836, lat=52.345268996730944
# No suitable images found for location: lon=5.461377, lat=51.559213
# No suitable images found for location: lon=5.46138, lat=51.55921
# No suitable images found for location: lon=5.4614, lat=51.5592
# No suitable images found for location: lon=5.461, lat=51.559
# Unable to retrieve data from the API with sufficient precision for location: lon=5.461376585738792, lat=51.559213486871386
# No suitable images found for location: lon=4.961091, lat=52.335463
# No suitable images found for location: lon=4.96109, lat=52.33546
# No suitable images found for location: lon=4.9611, lat=52.3355
# No suitable images found for location: lon=4.961, lat=52.335
# Unable to retrieve data from the API with sufficient precision for location: lon=4.961091015961169, lat=52.33546309784154
# No suitable images found for location: lon=5.633184, lat=51.667162
# No suitable images found for location: lon=5.63318, lat=51.66716
# No suitable images found for location: lon=5.6332, lat=51.6672
# No suitable images found for location: lon=5.633, lat=51.667
# Unable to retrieve data from the API with sufficient precision for location: lon=5.633183888217952, lat=51.66716238615072
# No suitable images found for location: lon=6.894428, lat=52.940529
# No suitable images found for location: lon=6.89443, lat=52.94053
# No suitable images found for location: lon=6.8944, lat=52.9405
# No suitable images found for location: lon=6.894, lat=52.941
# Unable to retrieve data from the API with sufficient precision for location: lon=6.894427532232791, lat=52.9405289816711
# No suitable images found for location: lon=5.551510, lat=51.631570
# No suitable images found for location: lon=5.55151, lat=51.63157
# No suitable images found for location: lon=5.5515, lat=51.6316
# No suitable images found for location: lon=5.552, lat=51.632
# Unable to retrieve data from the API with sufficient precision for location: lon=5.551510322170722, lat=51.63157000603928
# No suitable images found for location: lon=5.940186, lat=52.208252
# No suitable images found for location: lon=5.94019, lat=52.20825
# No suitable images found for location: lon=5.9402, lat=52.2083
# No suitable images found for location: lon=5.940, lat=52.208
# Unable to retrieve data from the API with sufficient precision for location: lon=5.940186262608363, lat=52.20825168209106
# No suitable images found for location: lon=6.315953, lat=51.951983
# No suitable images found for location: lon=6.31595, lat=51.95198
# No suitable images found for location: lon=6.3160, lat=51.9520
# No suitable images found for location: lon=6.316, lat=51.952
# Unable to retrieve data from the API with sufficient precision for location: lon=6.315952869568865, lat=51.951982784552925
# No suitable images found for location: lon=6.001775, lat=52.212788
# No suitable images found for location: lon=6.00178, lat=52.21279
# No suitable images found for location: lon=6.0018, lat=52.2128
# No suitable images found for location: lon=6.002, lat=52.213
# Unable to retrieve data from the API with sufficient precision for location: lon=6.001775302918723, lat=52.212787833333145
# No suitable images found for location: lon=5.875639, lat=52.415819
# No suitable images found for location: lon=5.87564, lat=52.41582
# No suitable images found for location: lon=5.8756, lat=52.4158
# No suitable images found for location: lon=5.876, lat=52.416
# Unable to retrieve data from the API with sufficient precision for location: lon=5.87563906780615, lat=52.41581884875455
# No suitable images found for location: lon=5.154068, lat=52.730064
# No suitable images found for location: lon=5.15407, lat=52.73006
# No suitable images found for location: lon=5.1541, lat=52.7301
# No suitable images found for location: lon=5.154, lat=52.730
# Unable to retrieve data from the API with sufficient precision for location: lon=5.154067938911127, lat=52.73006381673623
# No suitable images found for location: lon=6.039893, lat=51.261736
# No suitable images found for location: lon=6.03989, lat=51.26174
# No suitable images found for location: lon=6.0399, lat=51.2617
# No suitable images found for location: lon=6.040, lat=51.262
# Unable to retrieve data from the API with sufficient precision for location: lon=6.039893128625273, lat=51.261735538013326
# No suitable images found for location: lon=5.048538, lat=52.084813
# No suitable images found for location: lon=5.04854, lat=52.08481
# No suitable images found for location: lon=5.0485, lat=52.0848
# No suitable images found for location: lon=5.049, lat=52.085
# Unable to retrieve data from the API with sufficient precision for location: lon=5.0485383256358976, lat=52.08481255801723
# No suitable images found for location: lon=5.506171, lat=51.754358
# No suitable images found for location: lon=5.50617, lat=51.75436
# No suitable images found for location: lon=5.5062, lat=51.7544
# File already exists: /workspace/workspace/ufo-prediction/image_data_NLD_adv/1969.0_v0.1-NLD.8.47_1-5810_1.jpg. Skipping download.
# No suitable images found for location: lon=6.095594, lat=52.535789
# No suitable images found for location: lon=6.09559, lat=52.53579
# No suitable images found for location: lon=6.0956, lat=52.5358
# No suitable images found for location: lon=6.096, lat=52.536
# Unable to retrieve data from the API with sufficient precision for location: lon=6.095593757281501, lat=52.53578917957195
# No suitable images found for location: lon=4.821167, lat=52.355338
# No suitable images found for location: lon=4.82117, lat=52.35534
# No suitable images found for location: lon=4.8212, lat=52.3553
# No suitable images found for location: lon=4.821, lat=52.355
# Unable to retrieve data from the API with sufficient precision for location: lon=4.8211674862651765, lat=52.35533758405577
# No suitable images found for location: lon=6.346018, lat=52.409239
# No suitable images found for location: lon=6.34602, lat=52.40924
# No suitable images found for location: lon=6.3460, lat=52.4092
# No suitable images found for location: lon=6.346, lat=52.409
# Unable to retrieve data from the API with sufficient precision for location: lon=6.346018300527467, lat=52.40923883620137
# No suitable images found for location: lon=5.476843, lat=51.509780
# No suitable images found for location: lon=5.47684, lat=51.50978
# No suitable images found for location: lon=5.4768, lat=51.5098
# No suitable images found for location: lon=5.477, lat=51.510
# Unable to retrieve data from the API with sufficient precision for location: lon=5.476843124772856, lat=51.50977955359102
# No suitable images found for location: lon=6.566336, lat=52.590433
# No suitable images found for location: lon=6.56634, lat=52.59043
# No suitable images found for location: lon=6.5663, lat=52.5904
# No suitable images found for location: lon=6.566, lat=52.590
# Unable to retrieve data from the API with sufficient precision for location: lon=6.566335737427059, lat=52.59043287634699
# No suitable images found for location: lon=5.332282, lat=51.698528
# No suitable images found for location: lon=5.33228, lat=51.69853
# No suitable images found for location: lon=5.3323, lat=51.6985
# No suitable images found for location: lon=5.332, lat=51.699
# Unable to retrieve data from the API with sufficient precision for location: lon=5.332282223008609, lat=51.6985281641696
# No suitable images found for location: lon=4.317568, lat=52.088460
# No suitable images found for location: lon=4.31757, lat=52.08846
# No suitable images found for location: lon=4.3176, lat=52.0885
# No suitable images found for location: lon=4.318, lat=52.088
# Unable to retrieve data from the API with sufficient precision for location: lon=4.317567585224789, lat=52.08846026402125
# No suitable images found for location: lon=4.683812, lat=51.775028
# No suitable images found for location: lon=4.68381, lat=51.77503
# No suitable images found for location: lon=4.6838, lat=51.7750
# No suitable images found for location: lon=4.684, lat=51.775
# Unable to retrieve data from the API with sufficient precision for location: lon=4.683812235378129, lat=51.775027627509935
# No suitable images found for location: lon=4.019234, lat=51.375218
# No suitable images found for location: lon=4.01923, lat=51.37522
# No suitable images found for location: lon=4.0192, lat=51.3752
# No suitable images found for location: lon=4.019, lat=51.375
# Unable to retrieve data from the API with sufficient precision for location: lon=4.019234126734092, lat=51.37521782642999
# No suitable images found for location: lon=6.827592, lat=53.238301
# No suitable images found for location: lon=6.82759, lat=53.23830
# No suitable images found for location: lon=6.8276, lat=53.2383
# No suitable images found for location: lon=6.828, lat=53.238
# Unable to retrieve data from the API with sufficient precision for location: lon=6.8275920295756105, lat=53.23830118690215
# No suitable images found for location: lon=5.673125, lat=53.034261
# No suitable images found for location: lon=5.67313, lat=53.03426
# No suitable images found for location: lon=5.6731, lat=53.0343
# No suitable images found for location: lon=5.673, lat=53.034
# Unable to retrieve data from the API with sufficient precision for location: lon=5.673125234259475, lat=53.03426086233789
# No suitable images found for location: lon=3.712215, lat=51.714173
# No suitable images found for location: lon=3.71221, lat=51.71417
# No suitable images found for location: lon=3.7122, lat=51.7142
# No suitable images found for location: lon=3.712, lat=51.714
# Unable to retrieve data from the API with sufficient precision for location: lon=3.71221451704498, lat=51.71417310623263
# No suitable images found for location: lon=4.657839, lat=51.488005
# No suitable images found for location: lon=4.65784, lat=51.48800
# No suitable images found for location: lon=4.6578, lat=51.4880
# No suitable images found for location: lon=4.658, lat=51.488
# Unable to retrieve data from the API with sufficient precision for location: lon=4.6578385781574845, lat=51.48800486592412
# No suitable images found for location: lon=6.865076, lat=52.209983
# No suitable images found for location: lon=6.86508, lat=52.20998
# No suitable images found for location: lon=6.8651, lat=52.2100
# No suitable images found for location: lon=6.865, lat=52.210
# Unable to retrieve data from the API with sufficient precision for location: lon=6.865075905296277, lat=52.20998333242076
# No suitable images found for location: lon=4.091790, lat=51.836295
# No suitable images found for location: lon=4.09179, lat=51.83630
# No suitable images found for location: lon=4.0918, lat=51.8363
# No suitable images found for location: lon=4.092, lat=51.836
# Unable to retrieve data from the API with sufficient precision for location: lon=4.091790107486967, lat=51.83629500700516
# No suitable images found for location: lon=5.465133, lat=51.441747
# No suitable images found for location: lon=5.46513, lat=51.44175
# No suitable images found for location: lon=5.4651, lat=51.4417
# No suitable images found for location: lon=5.465, lat=51.442
# Unable to retrieve data from the API with sufficient precision for location: lon=5.465133375861036, lat=51.44174687467346
# No suitable images found for location: lon=6.070143, lat=52.163019
# No suitable images found for location: lon=6.07014, lat=52.16302
# No suitable images found for location: lon=6.0701, lat=52.1630
# No suitable images found for location: lon=6.070, lat=52.163
# Unable to retrieve data from the API with sufficient precision for location: lon=6.070142810171992, lat=52.16301913149577
# No suitable images found for location: lon=7.006415, lat=53.101611
# No suitable images found for location: lon=7.00642, lat=53.10161
# No suitable images found for location: lon=7.0064, lat=53.1016
# No suitable images found for location: lon=7.006, lat=53.102
# Unable to retrieve data from the API with sufficient precision for location: lon=7.006415474566103, lat=53.10161126935819
# No suitable images found for location: lon=4.813786, lat=52.451975
# No suitable images found for location: lon=4.81379, lat=52.45197
# No suitable images found for location: lon=4.8138, lat=52.4520
# No suitable images found for location: lon=4.814, lat=52.452
# Unable to retrieve data from the API with sufficient precision for location: lon=4.813785526750338, lat=52.45197485221649
# No suitable images found for location: lon=6.869903, lat=52.227571
# No suitable images found for location: lon=6.86990, lat=52.22757
# No suitable images found for location: lon=6.8699, lat=52.2276
# No suitable images found for location: lon=6.870, lat=52.228
# Unable to retrieve data from the API with sufficient precision for location: lon=6.869903291414026, lat=52.22757087943085
# No suitable images found for location: lon=5.065529, lat=51.550635
# No suitable images found for location: lon=5.06553, lat=51.55063
# No suitable images found for location: lon=5.0655, lat=51.5506
# No suitable images found for location: lon=5.066, lat=51.551
# Unable to retrieve data from the API with sufficient precision for location: lon=5.065529387020827, lat=51.55063454438714
# No suitable images found for location: lon=5.650297, lat=51.487369
# No suitable images found for location: lon=5.65030, lat=51.48737
# No suitable images found for location: lon=5.6503, lat=51.4874
# No suitable images found for location: lon=5.650, lat=51.487
# Unable to retrieve data from the API with sufficient precision for location: lon=5.650297178592819, lat=51.48736861657426
# No suitable images found for location: lon=5.713410, lat=52.425995
# No suitable images found for location: lon=5.71341, lat=52.42600
# No suitable images found for location: lon=5.7134, lat=52.4260
# No suitable images found for location: lon=5.713, lat=52.426
# Unable to retrieve data from the API with sufficient precision for location: lon=5.713410442731318, lat=52.425995215742105
# No suitable images found for location: lon=5.091268, lat=51.548839
# No suitable images found for location: lon=5.09127, lat=51.54884
# No suitable images found for location: lon=5.0913, lat=51.5488
# No suitable images found for location: lon=5.091, lat=51.549
# Unable to retrieve data from the API with sufficient precision for location: lon=5.091267672450642, lat=51.54883904378403
# No suitable images found for location: lon=6.562775, lat=53.013212
# No suitable images found for location: lon=6.56278, lat=53.01321
# No suitable images found for location: lon=6.5628, lat=53.0132
# No suitable images found for location: lon=6.563, lat=53.013
# Unable to retrieve data from the API with sufficient precision for location: lon=6.562775161399038, lat=53.01321220239819
# Image downloaded successfully: /workspace/workspace/ufo-prediction/image_data_NLD_adv/1910.0_v0.1-NLD.7.44_1-21402_1.jpg
# Image downloaded successfully: /workspace/workspace/ufo-prediction/image_data_NLD_adv/1910.0_v0.1-NLD.7.44_1-21402_2.jpg
# Image downloaded successfully: /workspace/workspace/ufo-prediction/image_data_NLD_adv/1910.0_v0.1-NLD.7.44_1-21402_3.jpg
# Image downloaded successfully: /workspace/workspace/ufo-prediction/image_data_NLD_adv/1910.0_v0.1-NLD.7.44_1-21402_4.jpg
# No suitable images found for location: lon=5.223490, lat=51.958652
# No suitable images found for location: lon=5.22349, lat=51.95865
# No suitable images found for location: lon=5.2235, lat=51.9587
# No suitable images found for location: lon=5.223, lat=51.959
# Unable to retrieve data from the API with sufficient precision for location: lon=5.22348995924936, lat=51.95865180528467
# No suitable images found for location: lon=3.881840, lat=51.470737
# No suitable images found for location: lon=3.88184, lat=51.47074
# No suitable images found for location: lon=3.8818, lat=51.4707
# No suitable images found for location: lon=3.882, lat=51.471
# Unable to retrieve data from the API with sufficient precision for location: lon=3.881840336874829, lat=51.47073736031568
# No suitable images found for location: lon=5.011169, lat=51.579945
# No suitable images found for location: lon=5.01117, lat=51.57994
# No suitable images found for location: lon=5.0112, lat=51.5799
# No suitable images found for location: lon=5.011, lat=51.580
# Unable to retrieve data from the API with sufficient precision for location: lon=5.011169266690769, lat=51.57994495684871
# No suitable images found for location: lon=5.210951, lat=52.135096
# No suitable images found for location: lon=5.21095, lat=52.13510
# No suitable images found for location: lon=5.2110, lat=52.1351
# No suitable images found for location: lon=5.211, lat=52.135
# Unable to retrieve data from the API with sufficient precision for location: lon=5.210950784684076, lat=52.13509562380042
# No suitable images found for location: lon=4.600103, lat=52.493450
# No suitable images found for location: lon=4.60010, lat=52.49345
# No suitable images found for location: lon=4.6001, lat=52.4934
# No suitable images found for location: lon=4.600, lat=52.493
# Unable to retrieve data from the API with sufficient precision for location: lon=4.600103288452601, lat=52.49344950714443
# No suitable images found for location: lon=6.629787, lat=53.237704
# No suitable images found for location: lon=6.62979, lat=53.23770
# No suitable images found for location: lon=6.6298, lat=53.2377
# No suitable images found for location: lon=6.630, lat=53.238
# Unable to retrieve data from the API with sufficient precision for location: lon=6.629787230513216, lat=53.23770447203992
# No suitable images found for location: lon=4.250471, lat=52.066069
# No suitable images found for location: lon=4.25047, lat=52.06607
# No suitable images found for location: lon=4.2505, lat=52.0661
# No suitable images found for location: lon=4.250, lat=52.066
# Unable to retrieve data from the API with sufficient precision for location: lon=4.25047147747377, lat=52.066068707626215
# No suitable images found for location: lon=5.316893, lat=51.718365
# No suitable images found for location: lon=5.31689, lat=51.71836
# No suitable images found for location: lon=5.3169, lat=51.7184
# No suitable images found for location: lon=5.317, lat=51.718
# Unable to retrieve data from the API with sufficient precision for location: lon=5.316893431804584, lat=51.71836484686218
# No suitable images found for location: lon=6.482465, lat=52.721940
# No suitable images found for location: lon=6.48247, lat=52.72194
# No suitable images found for location: lon=6.4825, lat=52.7219
# No suitable images found for location: lon=6.482, lat=52.722
# Unable to retrieve data from the API with sufficient precision for location: lon=6.482465352976099, lat=52.72193982991739
# No suitable images found for location: lon=5.120253, lat=51.758881
# No suitable images found for location: lon=5.12025, lat=51.75888
# No suitable images found for location: lon=5.1203, lat=51.7589
# No suitable images found for location: lon=5.120, lat=51.759
# Unable to retrieve data from the API with sufficient precision for location: lon=5.120252863869873, lat=51.75888062056734
# No suitable images found for location: lon=5.610129, lat=51.529861
# No suitable images found for location: lon=5.61013, lat=51.52986
# No suitable images found for location: lon=5.6101, lat=51.5299
# No suitable images found for location: lon=5.610, lat=51.530
# Unable to retrieve data from the API with sufficient precision for location: lon=5.610129252009732, lat=51.52986128960661
# No suitable images found for location: lon=5.861001, lat=50.769316
# No suitable images found for location: lon=5.86100, lat=50.76932
# No suitable images found for location: lon=5.8610, lat=50.7693
# No suitable images found for location: lon=5.861, lat=50.769
# Unable to retrieve data from the API with sufficient precision for location: lon=5.861000938087972, lat=50.76931611433223
# No suitable images found for location: lon=5.906031, lat=52.564625
# No suitable images found for location: lon=5.90603, lat=52.56463
# No suitable images found for location: lon=5.9060, lat=52.5646
# No suitable images found for location: lon=5.906, lat=52.565
# Unable to retrieve data from the API with sufficient precision for location: lon=5.906031056465993, lat=52.56462547309086
# No suitable images found for location: lon=6.546925, lat=52.484374
# No suitable images found for location: lon=6.54692, lat=52.48437
# No suitable images found for location: lon=6.5469, lat=52.4844
# No suitable images found for location: lon=6.547, lat=52.484
# Unable to retrieve data from the API with sufficient precision for location: lon=6.546924719649351, lat=52.48437428361569
# No suitable images found for location: lon=4.877735, lat=51.696049
# No suitable images found for location: lon=4.87773, lat=51.69605
# No suitable images found for location: lon=4.8777, lat=51.6960
# No suitable images found for location: lon=4.878, lat=51.696
# Unable to retrieve data from the API with sufficient precision for location: lon=4.877734909516718, lat=51.6960487584588
# No suitable images found for location: lon=5.745873, lat=51.282728
# No suitable images found for location: lon=5.74587, lat=51.28273
# No suitable images found for location: lon=5.7459, lat=51.2827
# No suitable images found for location: lon=5.746, lat=51.283
# Unable to retrieve data from the API with sufficient precision for location: lon=5.745872864542105, lat=51.28272795538851
# No suitable images found for location: lon=6.025015, lat=53.140592
# No suitable images found for location: lon=6.02501, lat=53.14059
# No suitable images found for location: lon=6.0250, lat=53.1406
# No suitable images found for location: lon=6.025, lat=53.141
# Unable to retrieve data from the API with sufficient precision for location: lon=6.025014656361299, lat=53.140592082962144
# No suitable images found for location: lon=5.691401, lat=51.375165
# No suitable images found for location: lon=5.69140, lat=51.37516
# No suitable images found for location: lon=5.6914, lat=51.3752
# No suitable images found for location: lon=5.691, lat=51.375
# Unable to retrieve data from the API with sufficient precision for location: lon=5.691401447536804, lat=51.37516487205298
# No suitable images found for location: lon=6.773662, lat=53.001395
# No suitable images found for location: lon=6.77366, lat=53.00140
# No suitable images found for location: lon=6.7737, lat=53.0014
# No suitable images found for location: lon=6.774, lat=53.001
# Unable to retrieve data from the API with sufficient precision for location: lon=6.7736623832905005, lat=53.001395400069946
# No suitable images found for location: lon=4.489510, lat=52.071978
# No suitable images found for location: lon=4.48951, lat=52.07198
# No suitable images found for location: lon=4.4895, lat=52.0720
# No suitable images found for location: lon=4.490, lat=52.072
# Unable to retrieve data from the API with sufficient precision for location: lon=4.489509806752976, lat=52.071978197306
# No suitable images found for location: lon=4.662931, lat=51.861922
# No suitable images found for location: lon=4.66293, lat=51.86192
# No suitable images found for location: lon=4.6629, lat=51.8619
# No suitable images found for location: lon=4.663, lat=51.862
# Unable to retrieve data from the API with sufficient precision for location: lon=4.662931198479175, lat=51.86192241697864
# No suitable images found for location: lon=4.917707, lat=52.427379
# No suitable images found for location: lon=4.91771, lat=52.42738
# No suitable images found for location: lon=4.9177, lat=52.4274
# No suitable images found for location: lon=4.918, lat=52.427
# Unable to retrieve data from the API with sufficient precision for location: lon=4.917706506114743, lat=52.42737917107943
# No suitable images found for location: lon=5.230646, lat=52.372466
# No suitable images found for location: lon=5.23065, lat=52.37247
# No suitable images found for location: lon=5.2306, lat=52.3725
# No suitable images found for location: lon=5.231, lat=52.372
# Unable to retrieve data from the API with sufficient precision for location: lon=5.23064616512754, lat=52.37246586035123
# No suitable images found for location: lon=5.663981, lat=50.846751
# No suitable images found for location: lon=5.66398, lat=50.84675
# No suitable images found for location: lon=5.6640, lat=50.8468
# No suitable images found for location: lon=5.664, lat=50.847
# Unable to retrieve data from the API with sufficient precision for location: lon=5.6639809797597085, lat=50.84675062286376
# No suitable images found for location: lon=6.654678, lat=52.342319
# No suitable images found for location: lon=6.65468, lat=52.34232
# No suitable images found for location: lon=6.6547, lat=52.3423
# No suitable images found for location: lon=6.655, lat=52.342
# Unable to retrieve data from the API with sufficient precision for location: lon=6.654677801936633, lat=52.34231873950321
# No suitable images found for location: lon=4.651265, lat=52.378130
# No suitable images found for location: lon=4.65127, lat=52.37813
# No suitable images found for location: lon=4.6513, lat=52.3781
# No suitable images found for location: lon=4.651, lat=52.378
# Unable to retrieve data from the API with sufficient precision for location: lon=4.65126528837282, lat=52.37813024245148
# No suitable images found for location: lon=5.490853, lat=52.213101
# No suitable images found for location: lon=5.49085, lat=52.21310
# No suitable images found for location: lon=5.4909, lat=52.2131
# No suitable images found for location: lon=5.491, lat=52.213
# Unable to retrieve data from the API with sufficient precision for location: lon=5.490852990132926, lat=52.21310132290748
# No suitable images found for location: lon=6.489388, lat=51.864414
# No suitable images found for location: lon=6.48939, lat=51.86441
# No suitable images found for location: lon=6.4894, lat=51.8644
# No suitable images found for location: lon=6.489, lat=51.864
# Unable to retrieve data from the API with sufficient precision for location: lon=6.489387630714754, lat=51.86441410301229
# No suitable images found for location: lon=6.648245, lat=52.532564
# No suitable images found for location: lon=6.64824, lat=52.53256
# No suitable images found for location: lon=6.6482, lat=52.5326
# No suitable images found for location: lon=6.648, lat=52.533
# Unable to retrieve data from the API with sufficient precision for location: lon=6.6482449814197375, lat=52.53256403980459
# No suitable images found for location: lon=4.342600, lat=51.811688
# No suitable images found for location: lon=4.34260, lat=51.81169
# No suitable images found for location: lon=4.3426, lat=51.8117
# No suitable images found for location: lon=4.343, lat=51.812
# Unable to retrieve data from the API with sufficient precision for location: lon=4.34259961703025, lat=51.811687885838005
# No suitable images found for location: lon=6.165376, lat=52.026683
# No suitable images found for location: lon=6.16538, lat=52.02668
# No suitable images found for location: lon=6.1654, lat=52.0267
# No suitable images found for location: lon=6.165, lat=52.027
# Unable to retrieve data from the API with sufficient precision for location: lon=6.165376177954355, lat=52.0266826164203
# No suitable images found for location: lon=5.630622, lat=51.528811
# No suitable images found for location: lon=5.63062, lat=51.52881
# No suitable images found for location: lon=5.6306, lat=51.5288
# No suitable images found for location: lon=5.631, lat=51.529
# Unable to retrieve data from the API with sufficient precision for location: lon=5.630622349583595, lat=51.52881053893651
# No suitable images found for location: lon=4.974532, lat=52.109450
# No suitable images found for location: lon=4.97453, lat=52.10945
# No suitable images found for location: lon=4.9745, lat=52.1094
# Image downloaded successfully: /workspace/workspace/ufo-prediction/image_data_NLD_adv/1900.0_v0.1-NLD.11.31_1-7786_1.jpg
# No suitable images found for location: lon=4.452340, lat=51.517943
# No suitable images found for location: lon=4.45234, lat=51.51794
# No suitable images found for location: lon=4.4523, lat=51.5179
# No suitable images found for location: lon=4.452, lat=51.518
# Unable to retrieve data from the API with sufficient precision for location: lon=4.452339656465348, lat=51.51794322817239
# No suitable images found for location: lon=4.856845, lat=51.648945
# No suitable images found for location: lon=4.85684, lat=51.64895
# No suitable images found for location: lon=4.8568, lat=51.6489
# No suitable images found for location: lon=4.857, lat=51.649
# Unable to retrieve data from the API with sufficient precision for location: lon=4.856844741111636, lat=51.64894521402275
# No suitable images found for location: lon=5.185607, lat=52.013512
# No suitable images found for location: lon=5.18561, lat=52.01351
# No suitable images found for location: lon=5.1856, lat=52.0135
# No suitable images found for location: lon=5.186, lat=52.014
# Unable to retrieve data from the API with sufficient precision for location: lon=5.185607460582296, lat=52.01351188875903
# No suitable images found for location: lon=6.578793, lat=52.246395
# No suitable images found for location: lon=6.57879, lat=52.24639
# No suitable images found for location: lon=6.5788, lat=52.2464
# No suitable images found for location: lon=6.579, lat=52.246
# Unable to retrieve data from the API with sufficient precision for location: lon=6.578792642201651, lat=52.24639483331824
# No suitable images found for location: lon=4.168112, lat=51.713505
# No suitable images found for location: lon=4.16811, lat=51.71350
# No suitable images found for location: lon=4.1681, lat=51.7135
# No suitable images found for location: lon=4.168, lat=51.714
# Unable to retrieve data from the API with sufficient precision for location: lon=4.168112034450962, lat=51.71350481478683
# No suitable images found for location: lon=4.017397, lat=51.474304
# No suitable images found for location: lon=4.01740, lat=51.47430
# No suitable images found for location: lon=4.0174, lat=51.4743
# No suitable images found for location: lon=4.017, lat=51.474
# Unable to retrieve data from the API with sufficient precision for location: lon=4.017397010328151, lat=51.47430422793016
# No suitable images found for location: lon=3.912974, lat=51.498974
# No suitable images found for location: lon=3.91297, lat=51.49897
# No suitable images found for location: lon=3.9130, lat=51.4990
# No suitable images found for location: lon=3.913, lat=51.499
# Unable to retrieve data from the API with sufficient precision for location: lon=3.912973925314712, lat=51.49897363507217
# No suitable images found for location: lon=5.895954, lat=51.829005
# No suitable images found for location: lon=5.89595, lat=51.82901
# No suitable images found for location: lon=5.8960, lat=51.8290
# No suitable images found for location: lon=5.896, lat=51.829
# Unable to retrieve data from the API with sufficient precision for location: lon=5.895954342240769, lat=51.82900532222716
# No suitable images found for location: lon=5.662398, lat=52.035132
# No suitable images found for location: lon=5.66240, lat=52.03513
# No suitable images found for location: lon=5.6624, lat=52.0351
# No suitable images found for location: lon=5.662, lat=52.035
# Unable to retrieve data from the API with sufficient precision for location: lon=5.662397847521753, lat=52.03513228881739
# No suitable images found for location: lon=4.694089, lat=52.293613
# No suitable images found for location: lon=4.69409, lat=52.29361
# No suitable images found for location: lon=4.6941, lat=52.2936
# No suitable images found for location: lon=4.694, lat=52.294
# Unable to retrieve data from the API with sufficient precision for location: lon=4.694089474830565, lat=52.29361300994603
# No suitable images found for location: lon=6.649548, lat=52.358894
# No suitable images found for location: lon=6.64955, lat=52.35889
# No suitable images found for location: lon=6.6495, lat=52.3589
# No suitable images found for location: lon=6.650, lat=52.359
# Unable to retrieve data from the API with sufficient precision for location: lon=6.649547742722667, lat=52.3588938074036
# No suitable images found for location: lon=5.405801, lat=51.878558
# No suitable images found for location: lon=5.40580, lat=51.87856
# No suitable images found for location: lon=5.4058, lat=51.8786
# No suitable images found for location: lon=5.406, lat=51.879
# Unable to retrieve data from the API with sufficient precision for location: lon=5.405801460189863, lat=51.87855802014289
# No suitable images found for location: lon=4.532568, lat=51.644596
# No suitable images found for location: lon=4.53257, lat=51.64460
# No suitable images found for location: lon=4.5326, lat=51.6446
# No suitable images found for location: lon=4.533, lat=51.645
# Unable to retrieve data from the API with sufficient precision for location: lon=4.532568065451242, lat=51.64459644469668
# No suitable images found for location: lon=4.386138, lat=51.509682
# No suitable images found for location: lon=4.38614, lat=51.50968
# No suitable images found for location: lon=4.3861, lat=51.5097
# No suitable images found for location: lon=4.386, lat=51.510
# Unable to retrieve data from the API with sufficient precision for location: lon=4.3861382888944265, lat=51.509681893439726
# No suitable images found for location: lon=6.386922, lat=52.308823
# No suitable images found for location: lon=6.38692, lat=52.30882
# No suitable images found for location: lon=6.3869, lat=52.3088
# No suitable images found for location: lon=6.387, lat=52.309
# Unable to retrieve data from the API with sufficient precision for location: lon=6.386921989084628, lat=52.30882343272617
# No suitable images found for location: lon=4.483181, lat=52.152324
# No suitable images found for location: lon=4.48318, lat=52.15232
# No suitable images found for location: lon=4.4832, lat=52.1523
# No suitable images found for location: lon=4.483, lat=52.152
# Unable to retrieve data from the API with sufficient precision for location: lon=4.483180753491549, lat=52.15232439466269
# No suitable images found for location: lon=4.776340, lat=51.821502
# No suitable images found for location: lon=4.77634, lat=51.82150
