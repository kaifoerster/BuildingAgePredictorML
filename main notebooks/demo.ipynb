# %% [raw]
# # Metadata for pretty-jupyter HTML rendering
# # pip install pretty-jupyter
# # jupyter nbconvert --to html --template pj demo.ipynb
#
# title: "Predicting building age with EUBUCCO footprints"
# output:
#     general:
#         input: true
#     html:
#         toc: true
#         code_folding: show
#         theme: paper # https://pretty-jupyter.readthedocs.io/en/latest/styling_settings.html#themes

# %% [markdown]
# Complete notebook available at: https://github.com/ai4up/ufo-prediction/blob/main/demo/demo.ipynb

# %% [markdown]
# ## Motivation
#
# Building attributes such as building height, type, and construction year are not available for all buildings in EUBUCCO. However, for many prospective use cases of the dataset, such as energy modeling, the building attributes are of high importance. This notebook shows how the available building footprints can be used to estimate missing building attributes with supervised machine learning.

# %%
# -.-|m { input: false }

# standard libs
import os
import sys
import logging
import gc

# project lib
PROJECT_SRC_PATH = os.path.join( '/workspace/workspace/ufo-prediction', 'src')
sys.path.append(PROJECT_SRC_PATH)

import visualizations
from prediction_age import AgePredictor, AgeClassifier, AgePredictorComparison
import preprocessing as pp
import dataset

# external libs
import numpy as np
import pandas as pd
import geopandas as gpd
from xgboost import XGBRegressor, XGBClassifier
import xgboost as xgb
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-psqi01dw because the default path (/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
# -.-|m { input: false }

logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## Data

# %% [markdown]
# Demo sample of ~20k buildings for Spain, ~50k for France, and 170k for the Netherlands. All 117 urban form features, lat lon, as well as some auxiliary attributes like city name, neighborhood, building type, etc. are included.
#
# The demo samples are stored using Git Large File Storage (LFS). To download them explicitly use:

# %%
# # When loading ufo data
# #DATA_DIR = '.'
# current_directory = os.getcwd()
# print(current_directory)

# path_data_NLD = os.path.join('/workspace/workspace/ufo-prediction', 'demo', 'df-NLD.pkl')
# path_data_FRA = os.path.join('/workspace/workspace/ufo-prediction', 'demo', 'df-FRA.pkl')
# path_data_ESP = os.path.join('/workspace/workspace/ufo-prediction', 'demo', 'df-ESP.pkl')
# print(path_data_NLD)
# Out:
# /workspace
# /workspace/workspace/ufo-prediction/demo/df-NLD.pkl

# %%
# df = pd.read_pickle(path_data_NLD)

# %%
path_data_RCA = os.path.join(dataset.DATA_DIR, 'rca-ufo-merge_ALL.csv')
df = pd.read_csv(path_data_RCA, encoding='latin1', low_memory=False)

# %%
df_temp = df.drop(dataset.RCA_FEATURES_SUB, axis=1)

# %%
df_temp2 = df_temp.drop(dataset.RCA_FEATURES_EXTRA, axis=1)

# %%
df_dropped = df_temp2.drop(dataset.RCA_FEATURES_SUBCAT, axis=1)

# %%
print(df_dropped.columns.to_list())
# Out:
# ['PropertyKey_ID', 'Deal_id', 'Property_id', 'country', 'residential_type', 'source_file', 'dist_to_closest_int', 'av_footprint_area_within_buffer_100', 'street_betweeness_global_max_within_buffer_500', 'av_elongation_within_buffer_500', 'std_building_footprint_city', 'block', 'blocks_2_to_4', 'street_closeness_500_av_within_buffer_500', 'street_width_std_within_buffer_100', 'av_footprint_area_within_buffer_500', 'street_length_total_within_buffer_500', 'BlockConvexity', 'buildings_within_buffer_500', 'StdBlockFootprintArea', 'street_closeness_global_closest_street', 'std_block_footprint_area_within_buffer_100', 'street_based_block_std_orientation_inter_buffer_100', 'street_length_std_within_buffer_100', 'AvBlockFootprintArea', 'std_block_length_within_buffer_100', 'street_betweeness_global_av_within_buffer_500', 'street_based_block_std_area_inter_buffer_500', 'street_length_closest_street', 'Elongation', 'age_right', 'BlockLength', 'street_closeness_500_closest_street', 'street_length_total_within_buffer_100', 'street_based_block_number_inter_buffer_100', 'street_length_av_within_buffer_500', 'blocks_10_to_19', 'country_right', 'street_closeness_500_max_within_buffer_500', 'av_block_length_within_buffer_100', 'street_width_av_within_buffer_100', 'blocks_5_to_9', 'std_block_av_footprint_area_within_buffer_100', 'street_based_block_av_phi_inter_buffer_100', 'std_block_av_footprint_area_within_buffer_500', 'street_based_block_av_area_inter_buffer_100', 'av_block_orientation_within_buffer_500', 'std_footprint_area_within_buffer_500', 'av_convexity_within_buffer_500', 'std_block_orientation_within_buffer_500', 'LongestAxisLength', 'blocks_within_buffer_500', 'av_block_orientation_within_buffer_100', 'n_detached_buildings', 'CountTouches', 'av_orientation_within_buffer_500', 'street_based_block_av_area_inter_buffer_500', 'SharedWallLength', 'street_based_block_phi', 'lat', 'street_based_block_std_phi_inter_buffer_100', 'street_betweeness_global_closest_street', 'street_based_block_std_phi_inter_buffer_500', 'av_convexity_within_buffer_100', 'av_block_footprint_area_within_buffer_100', 'av_block_length_within_buffer_500', 'distance_to_closest_street', 'total_number_block_city', 'Orientation', 'av_area_block_city', 'street_width_std_within_buffer_500', 'total_buildings_city', 'std_elongation_within_buffer_500', 'av_block_av_footprint_area_within_buffer_100', 'BlockOrientation', 'street_closeness_500_max_within_buffer_100', 'Perimeter', 'intersection_count_within_500', 'total_ft_area_within_buffer_500', 'height', 'street_betweeness_global_av_within_buffer_100', 'street_closeness_500_av_within_buffer_100', 'street_based_block_area', 'av_block_av_footprint_area_within_buffer_500', 'std_footprint_area_within_buffer_100', 'std_convexity_within_buffer_500', 'std_convexity_within_buffer_100', 'blocks_20_to_inf', 'blocks_within_buffer_100', 'std_area_block_city', 'street_width_av_closest_street', 'Unnamed: 0.1', 'av_elongation_within_buffer_100', 'street_based_block_std_orientation_inter_buffer_500', 'street_length_std_within_buffer_500', 'std_block_orientation_within_buffer_100', 'std_orientation_within_buffer_100', 'sbb', 'id_source', 'intersections_count', 'lon', 'FootprintArea', 'street_width_av_within_buffer_500', 'std_orientation_within_buffer_500', 'av_orientation_within_buffer_100', 'BlockPerimeter', 'Convexity', 'city', 'BlockLongestAxisLength', 'id_misaligned', 'street_based_block_number_inter_buffer_500', 'street_openness_closest_street', 'std_block_footprint_area_within_buffer_500', 'street_length_av_within_buffer_100', 'av_building_footprint_city', 'Corners', 'BlockTotalFootprintArea', 'id', 'total_ft_area_within_buffer_100', 'BlockCorners', 'street_width_std_closest_street', 'street_based_block_corners', 'BlockElongation', 'av_block_footprint_area_within_buffer_500', 'type_source', 'std_elongation_within_buffer_100', 'floors', 'std_block_length_within_buffer_500', 'av_length_street_city', 'intersection_count_within_100', 'build ...

# %% [markdown]
# ## Prediction

# %%
# xgb_model_params = {'tree_method': 'hist', 
#                     # 'n_estimators': 500
#                     }
# xgb_hyperparams = {
#     'max_depth': 5,
#     'learning_rate': 0.1,
#     'n_estimators': 500,
#     'colsample_bytree': 0.5,
#     'subsample': 1.0,
# }

xgb_model_params = {'tree_method': 'hist'}
xgb_hyperparams = {
    'max_depth': 13,
    'learning_rate': 0.025,
    'n_estimators': 1000,
    'colsample_bytree': 0.9,
    'colsample_bylevel': 0.5
}

# %% [markdown]
# ### Regression

# %%
predictor = AgePredictor(
    model=XGBRegressor(**xgb_model_params),
    df=df_dropped,
    test_training_split=pp.split_80_20,
    # cross_validation_split=pp.cross_validation,
    early_stopping=True,
    hyperparameters=xgb_hyperparams,
    # preprocessing_stages=[pp.remove_outliers, pp.categorical_to_int_byList, pp.convert_to_double_byList]
    preprocessing_stages=[pp.remove_outliers]
)

predictor.evaluate()
# Out:
# 2024-04-25 11:09:44,706 | INFO : Dataset length: 5749
# 2024-04-25 11:09:44,711 | INFO : Dataset allocated memory: 6 MB
# 2024-04-25 11:09:44,717 | INFO : No abort signal received. Continuing... To abort please create workspace/ufo-prediction/metadata/local-7f8448b7.abort.
# 2024-04-25 11:09:44,719 | INFO : Dataset standard deviation: 68.29702611746197
# 2024-04-25 11:09:44,719 | INFO : Dataset mean age: 1974.1440250478345
# 2024-04-25 11:09:44,720 | INFO : Training dataset length: 4599
# 2024-04-25 11:09:44,721 | INFO : Test dataset length: 1150
# 2024-04-25 11:09:44,738 | INFO : Test dataset standard deviation after preprocessing: 26.075371200286483
# 2024-04-25 11:09:44,739 | INFO : Test dataset mean age after preprocessing: 1985.5079812206573
# 2024-04-25 11:09:44,740 | INFO : Training dataset length after preprocessing: 4252
# 2024-04-25 11:09:44,740 | INFO : Test dataset length after preprocessing: 1065
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# 2024-04-25 11:10:00,150 | INFO : Energy need for heating in kWh/(m²a) R2: 0.6258
# 2024-04-25 11:10:00,151 | INFO : Energy need for heating in kWh/(m²a) MAPE: 0.3040
# 2024-04-25 11:10:00,151 | INFO : Energy need for heating in kWh/(m²a) MAE: 20.73
# 2024-04-25 11:10:00,151 | INFO : Energy need for heating in kWh/(m²a) RMSE: 35.59
# MAE: 14.29 y
# RMSE: 20.42 y
# R2: 0.3859
# Energy need for heating in kWh/(m²a) R2: 0.6258
# Energy need for heating in kWh/(m²a) MAPE: 0.3040
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Classification

# %%
tabula_nl_bins = [1900, 1965, 1975, 1992, 2006, 2015, 2022]
equally_sized_bins = [1900, 1945, 1970, 1980, 1990, 2000, 2010, 2051]

classifier = AgeClassifier(
    model=XGBClassifier(**xgb_model_params),
    df=df,
    test_training_split=pp.split_80_20,
    # cross_validation_split=pp.cross_validation,
    preprocessing_stages=[pp.remove_outliers],
    hyperparameters=xgb_hyperparams,
    mitigate_class_imbalance=True,
    # bin_config=equally_sized_bins,
    bins=equally_sized_bins,
)
classifier.evaluate(vmax=0.7)
# Out:
# 2024-04-25 11:11:29,990 | INFO : Generated bins: [1900, 1945, 1970, 1980, 1990, 2000, 2010, 2051]
# 2024-04-25 11:11:29,991 | INFO : Generated bins with the following labels: ['1900-1944', '1945-1969', '1970-1979', '1980-1989', '1990-1999', '2000-2009', '2010-2050']
# 2024-04-25 11:11:29,998 | INFO : Dataset length: 5749
# 2024-04-25 11:11:30,007 | INFO : Dataset allocated memory: 8 MB
# 2024-04-25 11:11:30,016 | INFO : No abort signal received. Continuing... To abort please create workspace/ufo-prediction/metadata/local-87c1c684.abort.
# 2024-04-25 11:11:30,017 | INFO : Training dataset length: 4599
# 2024-04-25 11:11:30,018 | INFO : Test dataset length: 1150
# 2024-04-25 11:11:30,020 | INFO : Test cities: ['Barcelona' 'Elche' 'ChenÃ\x83Â´ve' 'Ã\x83Â\x89vry' 'Utrecht' 'Amsterdam'
#  'Madrid' 'Almere' 'Ede' 'Yuncos' 'MÃ\x83Â³stoles' 'Haarlemmermeer'
#  'Rotterdam' 'Naaldwijk' 'Heerenveen' 'Venlo' 'Lochem'
#  'Saint-Arnoult-en-Yvelines' 'Moreuil' 'Aranjuez' 'Hilversum' 'Massanes'
#  'Palma de Mallorca (Islas Baleares)' 'Sevilla' 'Groningen'
#  'Saint-Herblain' 'Thorigny-sur-Marne' "'s-Gravenhage"
#  'Sant Esteve Sesrovires' 'Paris, 17e arrondissement'
#  'Paris, 19e arrondissement' 'Oss' 'Eindhoven'
#  'Cuenca (Castilla-La Mancha)' 'Nanteuil-le-Haudouin' 'Heerhugowaard'
#  'Marseille, 7e arrondissement' 'Leeuwarden'
#  'MÃ\x83Â¡laga (AndalucÃ\x83Â\xada)' 'Aix-en-Provence' 'Maastricht'
#  'Lorgues' 'Uden' 'Valencia' 'Nantes' 'Roermond' 'Nijmegen' 'Amstelveen'
#  'Brumath' 'Arnhem' 'Oviedo' 'Zwolle' "'s-Hertogenbosch" 'Helmond'
#  'Colmar' 'Zaltbommel' 'Bordeaux' 'Montrouge' 'Vlissingen'
#  'Issy-les-Moulineaux' 'Zaragoza' 'Granada' 'Beek'
#  'Chalon-sur-SaÃ\x83Â´ne' 'Soest' 'Oosterhout' 'Roosendaal' 'Lelystad'
#  'Woerden' 'Zoetermeer' 'Reyrieux' 'Tiel' 'ChambÃ\x83Â©ry'
#  'Puerto de la Cruz' 'Barendrecht' 'Amilly' 'Wijchen' 'Benidorm'
#  'Enschede' 'Sneek' 'Breukelen' 'Nieuwegein' 'Zeewolde' 'Roquetas de Mar'
#  'BÃ\x83Â©ziers  2e  Canton' 'Tilburg' 'Martigues-Ouest' 'LalÃ\x83Â\xadn'
#  'Toulouse' 'Mantes-la-Ville' 'AlmuÃ\x83Â±Ã\x83Â©car' 'Emmen'
#  'Valkenburg aan de Geul' 'Assen' 'Castries' 'Puig' 'Beaune'
#  'Pijnacker-Nootdorp' 'Harderwijk' 'LogroÃ\x83Â±o' 'Las Rozas de Madrid'
#  'Venray' 'Oud-Beijerland' 'Toulouse  8e  Canton' 'Rueil-Malmaison'
#  'Tarifa' 'Boxmeer' 'Torrevieja' 'Landgraaf' 'Apeldoorn'
#  'Lyon, 4e arrondissement' 'Almelo' 'Nunspeet' 'Purmerend' 'Narbonne'
#  'Le Bouscat' 'Villeurbanne' "L'Hospitalet de Llobregat" 'Leiden' 'Albi'
#  'Ripollet' 'Roubaix' 'Moerdijk' 'Alkmaar' 'Vigo' 'Beauvais' 'Le Mans'
#  'Doetinchem' 'Ermelo' 'San SebastiÃ\x83Â¡n de los Reyes'
#  'Cabanillas del Campo' 'Leidschendam-Voorburg' 'Schiedam' 'Halderberge'
#  'Santiago del Teide' 'Nice' 'Valladolid' 'El Prat de Llobregat'
#  'Steenwijkerland' 'Noordwijkerhout' 'San Fernando' 'Rennes-Sud-Est'
#  'Lingewaard' 'Amersfoort' 'Heerlen' 'Etten-Leur' 'Herencia'
#  'VÃ\x83Â©lez-MÃ\x83Â¡laga' 'Yvetot' 'Adeje' 'Haarlem' 'Waalwijk' 'Metz'
#  'Rennes' 'Geldermalsen' 'Saint-Maximin-la-Sainte-Baume' 'Houten'
#  'Manises' 'Ã\x83Â\x81vila' 'Middelburg' 'Alkemade' 'Ter Aar' 'Delft'
#  'Orange' 'Meyzieu' 'Pedrola' 'Veldhoven' 'Arganda del Rey' 'Blagnac'
#  'Kampen' 'Zaanstad' 'Saint-Omer' 'Cranendonck' 'BesanÃ\x83Â§on' 'Pornic'
#  'Paris, 16e arrondissement' 'Goes' 'Antigua' 'Barneveld' 'ThouarcÃ\x83Â©'
#  'Zevenaar' 'Antibes' 'Santa Margalida' 'Beuningen' 'Veendam' 'Vianen'
#  'Bergen op Zoom' 'Montpellier' 'Binnenmaas' 'Hellendoorn' 'LeganÃ\x83Â©s'
#  'Deventer' 'A CoruÃ\x83Â±a' 'Clermont-Ferrand' 'Les Ulis' 'Veenendaal'
#  'Chantilly' 'Miramar' 'Zeist' 'Gouda' 'Mandelieu-Cannes-Ouest'
#  'Alphen aan den Rijn' 'Trets' 'Jerez de la Frontera' 'Brielle'
#  'Ferney-Voltaire' 'La Oliva' 'Alicante' 'Waalre' 'Tordesillas'
#  'Alcobendas' 'Seynod' 'Lorca' 'Dos Hermanas' 'Veghel' 'Scherpenzeel'
#  'Son en Breugel' 'Sliedrecht' 'Haaksbergen' 'Santander' 'Rijnsburg'
#  'Cannes' 'Lyon, 8e arrondissement' 'Eersel' 'Godella' 'Valkenswaard'
#  'Echt-Susteren' 'Raalte' 'CÃ\x83Â³rdoba' 'Saint-Galmier' 'Zundert'
#  'San Miguel de Abona' 'Hengelo (Overijssel)' 'CalviÃ\x83Â\xa0'
#  'Beverwijk' 'Ã\x83Â\x89cully' 'Saint-Doulchard'
#  'AlenÃ\x83Â§on  3e  Canton' 'Teruel' 'Laxou' 'IngrÃ\x83Â©' 'Arques'
#  'Burgos' 'Ceuta' 'Le Havre' 'Brummen' 'Pouilly-en-Auxois'
#  'Badajoz (Extremadura)' 'Noisiel' 'Boulogne-Billancourt'
#  'Castanet-Tolosan' 'ChÃ\x83Â©cy' 'Montluel' 'Stadskanaal'
#  'AlcalÃ\x83Â¡ de Henares' 'Ryes' 'Clamart' 'Cergy' 'Palaiseau'
#  'Hoogeveen' 'Rivas-Vaciamadrid' 'Diemen' 'Opsterland' 'MasalavÃ\x83Â©s'
#  'Son Servera' 'Saint-Quentin' 'Charenton-le-Pont' 'Ault' 'Seclin'
#  'Pierrefitte-sur-Seine' 'Vila-rodona' 'Pulianas' 'Torija' 'Voerendaal'
#  'Groesbeek' 'Weert' 'Cozes' 'Bergh' 'Fuenlabrada'
#  'Marseille, 15e arrondissement' 'Rheden' 'Cromstrijen' 'AlcorcÃ\x83Â³n'
#  'Wormerland' 'AlmerÃ\x83Â\xada' 'Olst-Wijhe' 'ChÃ\x83Â¢teauroux-Est'
#  'Poitiers' 'Montfermeil' 'LliÃ\x83Â§Ã\x83Â\xa0 de Vall' 'Noord-Beveland'
#  'Ciudad Real' 'Sassenheim' 'Isigny-sur-Mer' 'Les Pennes-Mirabeau'
#  'Vlaardingen' 'Boxtel' 'Nancy' 'Hulst' 'Maurepas'
#  'Marseille, 13e arrondissement' 'Sant Cugat del VallÃ\x83Â¨s' 'Arcachon'
#  'Gonesse' 'Saumur-Sud' 'Bunnik' 'Marbella' 'Gemert-Bakel'
#  'Sittard-Geleen' 'Maasbree' 'Smallingerland' 'Naarden' 'Rosny-sous-Bois'
#  'Le Bar-sur-Loup' 'Ollioules' 'Wymbritseradiel' 'Maasdonk' 'Rijssen'
#  'Uithoorn' 'Getafe' 'Saint-Jean-de-Luz' 'CompiÃ\x83Â¨gne'
#  'Schouwen-Duiveland']
# 2024-04-25 11:11:30,032 | INFO : age_right attribute has been categorized (lowest age included: 1900; highest age included: 2050).
# 2024-04-25 11:11:30,041 | INFO : age_right attribute has been categorized (lowest age included: 1900; highest age included: 2050).
# 2024-04-25 11:11:30,057 | INFO : Training dataset length after preprocessing: 4252
# 2024-04-25 11:11:30,057 | INFO : Test dataset length after preprocessing: 1065
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# Classification report:
#                precision    recall  f1-score  support
# 1900-1944      0.475000  0.564356  0.515837      101
# 1945-1969      0.322034  0.400000  0.356808       95
# 1970-1979      0.303030  0.155039  0.205128      129
# 1980-1989      0.256410  0.243902  0.250000      123
# 1990-1999      0.373913  0.378855  0.376368      227
# 2000-2009      0.424149  0.509294  0.462838      269
# 2010-2050      0.329670  0.247934  0.283019      121
# accuracy       0.373709  0.373709  0.373709        0
# macro avg      0.354887  0.357054  0.350000     1065
# weighted avg   0.364377  0.373709  0.363748     1065
# Cohen’s kappa: 0.2426
# Matthews correlation coefficient (MCC): 0.2437
# FixedFormatter should only be used together with FixedLocator
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Country and generalization comparison

# %% [markdown]
# The `AgePredictorComparison` faciliates comparisons between differently configured training runs, for example to compare the prediction performance between countries, cross-validation strategies, oversampling strategies or any other preprocessing steps.

# %%
comparison_config = {
    'Spain': {'df': path_data_ESP},
    'France': {'df': path_data_FRA},
    'Netherlands': {'df': path_data_NLD},
}

grid_comparison_config = {
    'random-cv': {'cross_validation_split': pp.cross_validation},
    'neighborhood-cv': {'cross_validation_split': pp.neighborhood_cross_validation},
    'city-cv': {'cross_validation_split': pp.city_cross_validation},
}

comparison = AgePredictorComparison(
    exp_name='demo',
    model=XGBRegressor(**xgb_model_params),
    df=None,
    frac=0.5,
    cross_validation_split=None,
    preprocessing_stages=[pp.remove_outliers],
    hyperparameters=xgb_hyperparams,
    compare_feature_importance=False,
    compare_classification_error=False,
    include_baseline=False,
    save_results=False,
    garbage_collect_after_training=True,
    comparison_config=comparison_config,
    grid_comparison_config=grid_comparison_config,
)

results = comparison.evaluate()
# Out:
# 2024-01-17 14:50:47,195 | INFO : Starting experiment Spain_random-cv...
# 2024-01-17 14:53:18,314 | INFO : Dataset length: 4226188
# 2024-01-17 14:53:18,319 | INFO : Dataset allocated memory: 4385 MB
# 2024-01-17 14:53:20,237 | INFO : No abort signal received. Continuing... To abort please create /p/projects/eubucco/data/3-ml-inputs/local-33f2404e.abort.
# 2024-01-17 14:53:20,256 | INFO : Dataset standard deviation: 48.35942318636823
# 2024-01-17 14:53:20,263 | INFO : Dataset mean age: 1971.7313162594755
# 2024-01-17 14:53:20,264 | INFO : Training dataset length: 3380950
# 2024-01-17 14:53:20,264 | INFO : Test dataset length: 845238
# 2024-01-17 14:53:33,818 | INFO : Test dataset standard deviation after preprocessing: 25.909066171213233
# 2024-01-17 14:53:33,820 | INFO : Test dataset mean age after preprocessing: 1980.6306878251494
# 2024-01-17 14:53:33,821 | INFO : Training dataset length after preprocessing: 3058384
# 2024-01-17 14:53:33,821 | INFO : Test dataset length after preprocessing: 764264
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# 2024-01-17 14:54:57,119 | INFO : No abort signal received. Continuing... To abort please create /p/projects/eubucco/data/3-ml-inputs/local-33f2404e.abort.
# 2024-01-17 14:54:57,139 | INFO : Dataset standard deviation: 48.35942318636823
# 2024-01-17 14:54:57,145 | INFO : Dataset mean age: 1971.7313162594755
# 2024-01-17 14:54:57,146 | INFO : Training dataset length: 3380950
# 2024-01-17 14:54:57,147 | INFO : Test dataset length: 845238
# 2024-01-17 14:55:10,974 | INFO : Test dataset standard deviation after preprocessing: 25.863860350808892
# 2024-01-17 14:55:10,976 | INFO : Test dataset mean age after preprocessing: 1980.687527376331
# 2024-01-17 14:55:10,977 | INFO : Training dataset length after preprocessing: 3057845
# 2024-01-17 14:55:10,978 | INFO : Test dataset length after preprocessing: 764803
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# 2024-01-17 14:56:36,544 | INFO : No abort signal received. Continuing... To abort please create /p/projects/eubucco/data/3-ml-inputs/local-33f2404e.abort.
# 2024-01-17 14:56:36,564 | INFO : Dataset standard deviation: 48.35942318636823
# 2024-01-17 14:56:36,570 | INFO : Dataset mean age: 1971.7313162594755
# 2024-01-17 14:56:36,571 | INFO : Training dataset length: 3380950
# 2024-01-17 14:56:36,572 | INFO : Test dataset length: 845238
# 2024-01-17 14:56:50,781 | INFO : Test dataset standard deviation after preprocessing: 25.841739231343904
# 2024-01-17 14:56:50,783 | INFO : Test dataset mean age after preprocessing: 1980.7072634222238
# 2024-01-17 14:56:50,784 | INFO : Training dataset length after preprocessing: 3058449
# 2024-01-17 14:56:50,785 | INFO : Test dataset length after preprocessing: 764199
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# 2024-01-17 14:58:20,001 | INFO : No abort signal received. Continuing... To abort please create /p/projects/eubucco/data/3-ml-inputs/local-33f2404e.abort.
# 2024-01-17 14:58:20,021 | INFO : Dataset standard deviation: 48.35942318636823
# 2024-01-17 14:58:20,028 | INFO : Dataset mean age: 1971.7313162594755
# 2024-01-17 14:58:20,028 | INFO : Training dataset length: 3380951
# 2024-01-17 14:58:20,029 | INFO : Test dataset length: 845237
# 2024-01-17 14:58:33,937 | INFO : Test dataset standard deviation after preprocessing: 25.885942958995326
# 2024-01-17 14:58:33,940 | INFO : Test dataset mean age after preprocessing: 1980.6330461100604
# 2024-01-17 14:58:33,940 | INFO : Training dataset length after preprocessing: 3058086
# 2024-01-17 14:58:33,941 | INFO : Test dataset length after preprocessing: 764562
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# 2024-01-17 15:00:00,102 | INFO : No abort signal received. Continuing... To abort please create /p/projects/eubucco/data/3-ml-inputs/local-33f2404e.abort.
# 2024-01-17 15:00:00,122 | INFO : Dataset standard deviation: 48.35942318636823
# 2024-01-17 15:00:00,129 | INFO : Dataset mean age: 1971.7313162594755
# 2024-01-17 15:00:00,130 | INFO : Training dataset length: 3380951
# 2024-01-17 15:00:00,131 | INFO : Test dataset length: 845237
# 2024-01-17 15:00:13,908 | INFO : Test dataset standard deviation after preprocessing: 25.87389780947648
# 2024-01-17 15:00:13,910 | INFO : Test dataset mean age after preprocessing: 1980.6614314479225
# 2024-01-17 15:00:13,910 | INFO : Training dataset length after preprocessing: 3057828
# 2024-01-17 15:00:13,911 | INFO : Test dataset length after preprocessing: 764820
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# 2024-01-17 15:01:46,432 | INFO : Starting experiment France_random-cv...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [21], line 13
#       1 comparison_config = {
#       2     'Spain': {'df': path_data_ESP},
#       3     'France': {'df': path_data_FRA},
#       4     'Netherlands': {'df': path_data_NLD},
#       5 }
#       7 grid_comparison_config = {
#       8     'random-cv': {'cross_validation_split': pp.cross_validation},
#       9     'neighborhood-cv': {'cross_validation_split': pp.neighborhood_cross_validation},
#      10     'city-cv': {'cross_validation_split': pp.city_cross_validation},
#      11 }
# ---> 13 comparison = AgePredictorComparison(
#      14     exp_name='demo',
#      15     model=XGBRegressor(**xgb_model_params),
#      16     df=None,
#      17     frac=0.5,
#      18     cross_validation_split=None,
#      19     preprocessing_stages=[pp.remove_outliers],
#      20     hyperparameters=xgb_hyperparams,
#      21     compare_feature_importance=False,
#      22     compare_classification_error=False,
#      23     include_baseline=False,
#      24     save_results=False,
#      25     garbage_collect_after_training=True,
#      26     comparison_config=comparison_config,
#      27     grid_comparison_config=grid_comparison_config,
#      28 )
#      30 results = comparison.evaluate()
#
# File ~workspace/workspace/ufo-prediction/src/prediction_age.py:208, in AgePredictorComparison.__init__(self, compare_error_distribution, compare_fit_time, compare_energy_error, compare_spatial_autocorrelation, compare_classification_error, *args, **kwargs)
#     206 self.compare_spatial_autocorrelation = compare_spatial_autocorrelation
#     207 self.compare_classification_error = compare_classification_error
# --> 208 super().__init__(*args, **kwargs, predictor_type=AgePredictor)
#
# File ~workspace/workspace/ufo-prediction/src/prediction.py:759, in PredictorComparison.__init__(self, predictor_type, comparison_config, grid_comparison_config, exp_name, compare_feature_importance, garbage_collect_after_training, save_results, keep_predictor_in_memory, include_baseline, n_seeds, **baseline_kwargs)
#     756 self.comparison_metrics = []
#     757 self.exp_name = exp_name or utils.truncated_uuid4()
# --> 759 self._compare()
#
# File ~workspace/workspace/ufo-prediction/src/prediction.py:782, in PredictorComparison._compare(self)
#     780 dataset.GLOBAL_REPRODUCIBILITY_SEED = seed
#     781 dataset.FEATURES = features # reset features to original state if they have been modified by another experiment
# --> 782 self.predictors[name].append(self.predictor_type(**kwargs))
#     784 if self.compare_feature_importance:
#     785     self.predictors[name][seed].calculate_SHAP_values()
#
# File ~workspace/workspace/ufo-prediction/src/prediction_age.py:24, in AgePredictor.__init__(self, *args, **kwargs)
#      23 def __init__(self, *args, **kwargs):
# ---> 24     super().__init__(*args, **kwargs, target_attribute=dataset.AGE_ATTRIBUTE)
#
# File ~workspace/workspace/ufo-prediction/src/prediction.py:479, in Regressor.__init__(self, *args, **kwargs)
#     478 def __init__(self, *args, **kwargs):
# --> 479     super().__init__(*args, **kwargs)
#
# File ~workspace/workspace/ufo-prediction/src/prediction.py:84, in Predictor.__init__(self, model, df, frac, n_cities, test_set, test_training_split, cross_validation_split, preprocessing_stages, target_attribute, mitigate_class_imbalance, early_stopping, hyperparameter_n_iter, hyperparameter_tuning_space, hyperparameter_tuning_only, hyperparameters, initialize_only)
#      81 self.hyperparameter_tuning_results = None
#      83 if not initialize_only:
# ---> 84     self._e2e_training()
#
# File ~workspace/workspace/ufo-prediction/src/prediction.py:88, in Predictor._e2e_training(self)
#      87 def _e2e_training(self):
# ---> 88     self._load()
#      89     self._clean()
#      90     # self._preprocess_before_splitting()
#
# File ~workspace/workspace/ufo-prediction/src/prediction.py:103, in Predictor._load(self)
#     101 def _load(self):
#     102     if isinstance(self.df, str):
# --> 103         self.df = utils.load_df(self.df)
#     105     if isinstance(self.test_set, str):
#     106         self.test_set = utils.load_df(self.test_set)
#
# File ~workspace/workspace/ufo-prediction/src/utils.py:209, in load_df(df_path)
#     206     return pd.read_csv(df_path)
#     208 if '.pkl' in df_path:
# --> 209     return pd.read_pickle(df_path)
#     211 if '.parquet' in df_path:
#     212     return pd.read_parquet(df_path)
#
# File ~.local/lib/python3.8/site-packages/pandas/io/pickle.py:179, in read_pickle(filepath_or_buffer, compression, storage_options)
#     115 """
#     116 Load pickled pandas object (or any object) from file.
#     117
#    (...)
#     176 4    4    9
#     177 """
#     178 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 179 with get_handle(
#     180     filepath_or_buffer,
#     181     "rb",
#     182     compression=compression,
#     183     is_text=False,
#     184     storage_options=storage_options,
#     185 ) as handles:
#     186     # 1) try standard library Pickle
#     187     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     188     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     190     try:
#     191         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     192         try:
#
# File ~.local/lib/python3.8/site-packages/pandas/io/common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspace/workspace/ufo-prediction/demo/df-FRA.pkl'

# %%
results
# Out:
#                           name        R2  R2_std        MAE  MAE_std  \
# 8          Netherlands_city-cv  0.135401     0.0  18.030643      0.0
# 7               France_city-cv  0.187767     0.0  18.645831      0.0
# 6                Spain_city-cv  0.197072     0.0  23.840955      0.0
# 3        Spain_neighborhood-cv  0.198503     0.0  23.779078      0.0
# 5  Netherlands_neighborhood-cv  0.304538     0.0  15.884060      0.0
# 4       France_neighborhood-cv  0.330228     0.0  16.306574      0.0
# 0              Spain_random-cv  0.363164     0.0  20.108252      0.0
# 1             France_random-cv  0.511105     0.0  12.372172      0.0
# 2        Netherlands_random-cv  0.575725     0.0  10.203823      0.0
#
#         RMSE  RMSE_std  within_5_years  within_10_years  within_20_years  \
# 8  23.598668       0.0        0.221385         0.392977         0.638903
# 7  23.772030       0.0        0.176875         0.345911         0.615315
# 6  29.563272       0.0        0.126411         0.247178         0.494357
# 3  29.536916       0.0        0.129797         0.247178         0.506772
# 5  21.164937       0.0        0.241489         0.444702         0.699700
# 4  21.586864       0.0        0.211348         0.408337         0.705209
# 0  26.328608       0.0        0.180587         0.355530         0.592551
# 1  18.443089       0.0        0.369564         0.593466         0.806340
# 2  16.531180       0.0        0.525335         0.695626         0.827052
#
#    R2_seed_0
# 8   0.135401
# 7   0.187767
# 6   0.197072
# 3   0.198503
# 5   0.304538
# 4   0.330228
# 0   0.363164
# 1   0.511105
# 2   0.575725

# %%
del comparison, predictor, classifier, results, df, df_temp, df_temp2, df_dropped
gc.collect()
